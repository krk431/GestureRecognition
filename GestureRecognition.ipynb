# %% [markdown]
# <a href="https://colab.research.google.com/github/krk431/GestureRecognition/blob/main/GestureRecognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import os
from PIL import Image
import imageio
import datetime
import os
from PIL import Image, ImageFilter, ImageEnhance
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
import os
os.environ['PYTHONHASHSEED']="30"
np.random.seed(30)
import random as rn
rn.seed(30)
import tensorflow as tf
tf.random.set_seed(30)
from keras import backend as K

# %%
# train and validatiaon data creator with ablation
# when ablation is 10, then 10 folders for each label will be selected.
def get_data(path, ablation=None):
    train_doc = np.random.permutation(open(path+'train.csv').readlines())
    val_doc = np.random.permutation(open(path+'val.csv').readlines())
    counts = np.zeros(5) # count for loading folders for 5 classes
    train_data = []
    val_data = []
    # when ablation is None pass full training and val data
    if ablation is not None:
        # iterating train doc
        for doc in train_doc:
            lable = int(doc.strip().split(';')[2])
            if counts[lable] < ablation:
                train_data.append(doc)
                counts[lable] += 1
        counts = np.zeros(5)
        # iterating val doc
        for doc in val_doc:
            lable = int(doc.strip().split(';')[2])
            if counts[lable] < ablation:
                val_data.append(doc)
                counts[lable] += 1
    else:
        train_data, val_data = train_doc, val_doc
    return train_data, val_data

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !ls "/content/drive/My Drive/Colab Notebooks/DL/Project_data/"
# Out:
# train  train.csv  val  val.csv

# %%
train_doc, val_doc = get_data('/content/drive/My Drive/Colab Notebooks/DL/Project_data/', ablation=None)
batch_size = 32 # experiment with the batch size
enable_augmentation = False # augmentation of Data
# sequence ids
# selecting alternate frames from 7 to 26.
seq_idx = range(7,26,2)
# image dimensions
dim_x, dim_y = 120, 120

# %%
def generator(source_path, folder_list, batch_size, is_train = False, augmention = False, debug=False):
    # print('\nSource path = ', source_path, '; batch size =', batch_size)
    img_idx = seq_idx #create a list of image numbers you want to use for a particular video
    x = len(img_idx)
    y, z = dim_x, dim_y
    while True:
        # doubling the data for augmentation
        if is_train and augmention:
            t = np.concatenate((np.random.permutation(folder_list), np.random.permutation(folder_list)))
        else:
            t = np.random.permutation(folder_list)

        if (len(t)%batch_size) == 0:
            num_batches = int(len(t)/batch_size)
        else:
            num_batches = len(t)//batch_size + 1

        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                if debug:
                    plt.figure(figsize=(20,5))
                #handling remaining datapoints
                folder_idx = folder + (batch*batch_size)
                if folder_idx >= len(t):
                    break
                folder_str = t[folder_idx]
                imgs = os.listdir(source_path+'/'+ folder_str.split(';')[0]) # read all the images in the folder
                # randomly enabling augmentation and augmentation type
                aug_type = None
                if is_train and augmention and rn.randint(0,1) == 1:
                    aug_type = rn.randint(0, 4) #randomly selecting augmentation type
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imageio.imread(os.path.join(source_path, folder_str.strip().split(';')[0], imgs[item])).astype(np.float32)
                    #image_object = Image.open(source_path+'/'+ folder_str.strip().split(';')[0]+'/'+imgs[item])
                    #image = np.array(image_object, dtype=np.float32)

                    # plotting original images for debugging purpose only
                    if debug:
                        plt.subplot(2, x, idx+1)
                        plt.imshow(image.astype('uint8'))

                    #crop the images and resize them. Note that the images are of 2 different shape
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    # making the rectangle images into square by cropping sides
                    # so the aspect ration can be mantained while resizing.
                    if image.shape[1] > image.shape[0]:
                        diff_px = image.shape[1] - image.shape[0]
                        crop_start = diff_px//2
                        crop_end = crop_start + image.shape[0]
                        image = image[:, crop_start:crop_end]
                    elif image.shape[0] > image.shape[1]:
                        diff_px = image.shape[0] - image.shape[1]
                        crop_start = diff_px//2
                        crop_end = crop_start + image.shape[1]
                        image = image[:, crop_start:crop_end]

                    image_pil = Image.fromarray(image.astype('uint8'))
                    resized_im = image_pil.resize((y,z))

                    if aug_type is not None:
                        if aug_type == 0: # edge Enhancement
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.EDGE_ENHANCE))
                        elif aug_type == 1: # adding gaussian blur
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.GaussianBlur(1)))
                        elif aug_type == 2: # enchancing image detailing
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.DETAIL))
                        elif aug_type == 3: # sharpening image
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.SHARPEN))
                        elif aug_type == 4: # Brightness enhancement
                            resized_im = np.array(ImageEnhance.Brightness((Image.fromarray(resized_im, 'RGB'))).enhance(1.5))
                    # plotting rezised images for debugging purpose only
                    if debug:
                        plt.subplot(2, x, idx+x+1)
                        plt.imshow(resized_im)

                    resized_im = np.array(resized_im, dtype=np.float32)

                    batch_data[folder,idx,:,:,0] = resized_im[:,:,0]/255.0 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = resized_im[:,:,1]/255.0 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = resized_im[:,:,2]/255.0 #normalise and feed in the image

                batch_labels[folder, int(folder_str.strip().split(';')[2])] = 1
            yield batch_data, batch_labels

# %%
curr_dt_time = datetime.datetime.now()
train_path = '/content/drive/My Drive/Colab Notebooks/DL/Project_data/train' #'/notebooks/storage/Final_data/Collated_training/train'
val_path =  '/content/drive/My Drive/Colab Notebooks/DL/Project_data/val' #'/notebooks/storage/Final_data/Collated_training/val'

#multiply number train seq by 2 when using augmentation
multiplier = 1
if enable_augmentation:
    multiplier = 2
num_train_sequences = len(train_doc)*multiplier
print('# training sequences =', num_train_sequences)

num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)

num_epochs = 50 # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 50

# %%
# testing generative
test_gen = generator(train_path, train_doc, 1, is_train = True, augmention = True, debug = True)
d = next(test_gen)[0]

# %% [markdown]
# ##Model

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Bidirectional, BatchNormalization, Activation, Dropout, GlobalAveragePooling2D, GlobalAveragePooling3D, ConvLSTM2D
from tensorflow.keras.layers import Conv2D, Conv3D, MaxPooling2D, MaxPooling3D
#from keras.layers.convolutional import Conv2D, Conv3D, MaxPooling2D, MaxPooling3D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers

#input shape for the st layer
input_shape = (len(seq_idx), dim_x, dim_y, 3)
np.random.seed(30)

# %% [markdown]
# ###Experiment 1

# %% [markdown]
# ##Conv3d

# %%
# model = Sequential()
# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(MaxPooling3D(pool_size=2))

# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=2))

# model.add(Flatten())
# model.add(Dense(256, activation='relu'))
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ###Experiment 2

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# model.add(Conv3D(256, kernel_size=(3, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(3, 2, 2)))

# model.add(Conv3D(512, kernel_size=(3, 3, 3), activation='relu'))
# model.add(Conv3D(512, kernel_size=(3, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ###Experiment 3

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))

# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment 4

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(BatchNormalization())

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())

# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment 5

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(BatchNormalization())
# #model.add(Dropout(0.2))
# model.add(Dropout(0.5))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# #model.add(Dropout(0.2))
# model.add(Dropout(0.5))

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# #model.add(Dropout(0.2))
# model.add(Dropout(0.5))

# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# #model.add(Dropout(0.2))
# model.add(Dropout(0.5))

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ###Experiment 6

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment 7

# %%
# loss: 0.1388 - categorical_accuracy: 0.9539 - val_loss: 0.1661 - val_categorical_accuracy: 0.9297
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(GlobalAveragePooling3D())
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment 8

# %% [markdown]
# ###TimeDistributed Conv2D + GRU

# %%
# model = Sequential()
# model.add(TimeDistributed(
#     Conv2D(32, (3,3), activation='relu'), input_shape=input_shape)
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())

# model.add(TimeDistributed(
#     Conv2D(64, (3,3), activation='relu'))
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())

# model.add(TimeDistributed(GlobalAveragePooling2D()))
# model.add(TimeDistributed(Dense(64, activation='relu')))
# model.add(BatchNormalization())

# model.add(GRU(128))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ###Experiment 9
# ### TimeDistributed + ConvLSTM2D

# %%
# model = Sequential()
# model.add(TimeDistributed(
#     Conv2D(8, (3,3), activation='relu'), input_shape=input_shape)
# )
# model.add(BatchNormalization())
# model.add(TimeDistributed(
#     Conv2D(16, (3,3), activation='relu'))
# )
# model.add(BatchNormalization())
# model.add(
#     ConvLSTM2D(8, kernel_size = 3, return_sequences=False)
# )
# model.add(BatchNormalization())
# model.add(TimeDistributed(
#     Dense(64, activation='relu'))
# )
# model.add(BatchNormalization())
# model.add(GlobalAveragePooling2D())
# model.add(Dense(64, activation='relu'))
# model.add(Dense(5, activation='softmax'))

# %%
model = Sequential()
model.add(TimeDistributed(
    Conv2D(8, (3,3), activation='relu'), input_shape=input_shape)
)
model.add(BatchNormalization())
model.add(TimeDistributed(
    Conv2D(16, (3,3), activation='relu'))
)
model.add(BatchNormalization())
model.add(
    ConvLSTM2D(8, kernel_size = 3, return_sequences=False)
)
model.add(BatchNormalization())
model.add(TimeDistributed(
    Dense(64, activation='relu'))
)
model.add(BatchNormalization())
model.add(GlobalAveragePooling2D())
model.add(Dense(64, activation='relu'))
model.add(Dense(5, activation='softmax'))

# %%
#optimiser = optimizers.Adam(lr=0.01) #write your optimizer
#model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ time_distributed (TimeDistributed)   │ (None, 10, 118, 118, 8)     │             224 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 10, 118, 118, 8)     │              32 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_1 (TimeDistributed) │ (None, 10, 116, 116, 16)    │           1,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 10, 116, 116, 16)    │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_lstm2d (ConvLSTM2D)             │ (None, 114, 114, 8)         │           6,944 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 114, 114, 8)         │              32 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_2 (TimeDistributed) │ (None, 114, 114, 64)        │             576 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 114, 114, 64)        │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 64)                  │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 5)                   │             325 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 13,781 (53.83 KB)
#  Trainable params: 13,589 (53.08 KB)
#  Non-trainable params: 192 (768.00 B)
# None

# %%
train_generator = generator(train_path, train_doc, batch_size, is_train = True, augmention = enable_augmentation)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_init_exp_16' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'

if not os.path.exists(model_name):
    os.mkdir(model_name)

filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.keras'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto')

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001, verbose=1)

callbacks_list = [checkpoint, LR]

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %%
# Compile the model
model.compile(optimizer='adam',              # Optimizer
              loss='categorical_crossentropy',  # Loss function for multi-class classification
              metrics=['categorical_accuracy'])

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
                        callbacks=callbacks_list, validation_data=val_generator,
                        validation_steps=validation_steps, class_weight=None,  initial_epoch=0)
# Out:
# Epoch 1/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 233s/step - categorical_accuracy: 0.2506 - loss: 1.5959
# Epoch 1: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00001-1.53930-0.30357-1.25486-0.14062.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 5497s 273s/step - categorical_accuracy: 0.2530 - loss: 1.5933 - val_categorical_accuracy: 0.1406 - val_loss: 1.2549 - learning_rate: 0.0010
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.4705 - loss: 1.3917
# Epoch 2: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00002-1.35774-0.44345-1.25084-0.14844.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - categorical_accuracy: 0.4692 - loss: 1.3901 - val_categorical_accuracy: 0.1484 - val_loss: 1.2508 - learning_rate: 0.0010
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.5205 - loss: 1.2276
# Epoch 3: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00003-1.20101-0.50149-1.23638-0.17969.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 53s 3s/step - categorical_accuracy: 0.5197 - loss: 1.2264 - val_categorical_accuracy: 0.1797 - val_loss: 1.2364 - learning_rate: 0.0010
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.5586 - loss: 1.0771
# Epoch 4: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00004-1.06114-0.53869-1.23714-0.14062.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 55s 3s/step - categorical_accuracy: 0.5577 - loss: 1.0764 - val_categorical_accuracy: 0.1406 - val_loss: 1.2371 - learning_rate: 0.0010
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.5956 - loss: 1.0245
# Epoch 5: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00005-1.00696-0.57887-1.25666-0.13281.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 55s 3s/step - categorical_accuracy: 0.5948 - loss: 1.0237 - val_categorical_accuracy: 0.1328 - val_loss: 1.2567 - learning_rate: 0.0010
# Epoch 6/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.5853 - loss: 0.9232
# Epoch 6: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00006-0.94390-0.57143-1.24105-0.23438.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - categorical_accuracy: 0.5847 - loss: 0.9241 - val_categorical_accuracy: 0.2344 - val_loss: 1.2411 - learning_rate: 0.0010
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6361 - loss: 0.9050
# Epoch 7: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00007-0.87941-0.64732-1.28024-0.16406.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 55s 3s/step - categorical_accuracy: 0.6366 - loss: 0.9038 - val_categorical_accuracy: 0.1641 - val_loss: 1.2802 - learning_rate: 0.0010
# Epoch 8/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.6939 - loss: 0.8080
# Epoch 8: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00008-0.82207-0.67113-1.25791-0.24219.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - categorical_accuracy: 0.6929 - loss: 0.8087 - val_categorical_accuracy: 0.2422 - val_loss: 1.2579 - learning_rate: 0.0010
# Epoch 9/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6880 - loss: 0.7780
# Epoch 9: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00009-0.77356-0.67857-1.31228-0.25000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 55s 3s/step - categorical_accuracy: 0.6876 - loss: 0.7778 - val_categorical_accuracy: 0.2500 - val_loss: 1.3123 - learning_rate: 0.0010
# Epoch 10/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7431 - loss: 0.7103
# Epoch 10: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00010-0.74655-0.71280-1.35493-0.18750.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - categorical_accuracy: 0.7418 - loss: 0.7119 - val_categorical_accuracy: 0.1875 - val_loss: 1.3549 - learning_rate: 0.0010
# Epoch 11/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7615 - loss: 0.6829
# Epoch 11: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00011-0.68433-0.71875-1.45559-0.17188.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 55s 3s/step - categorical_accuracy: 0.7595 - loss: 0.6830 - val_categorical_accuracy: 0.1719 - val_loss: 1.4556 - learning_rate: 0.0010
# Epoch 12/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7599 - loss: 0.6464
# Epoch 12: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00012-0.65642-0.73958-1.45173-0.17969.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - categorical_accuracy: 0.7589 - loss: 0.6469 - val_categorical_accuracy: 0.1797 - val_loss: 1.4517 - learning_rate: 0.0010
# Epoch 13/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7879 - loss: 0.6258
# Epoch 13: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00013-0.61660-0.76935-1.73305-0.17188.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - categorical_accuracy: 0.7870 - loss: 0.6254 - val_categorical_accuracy: 0.1719 - val_loss: 1.7330 - learning_rate: 0.0010
# Epoch 14/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8073 - loss: 0.5727
# Epoch 14: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00014-0.58343-0.78274-1.74710-0.17969.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - categorical_accuracy: 0.8062 - loss: 0.5732 - val_categorical_accuracy: 0.1797 - val_loss: 1.7471 - learning_rate: 0.0010
# Epoch 15/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7695 - loss: 0.5975
# Epoch 15: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00015-0.61204-0.74851-1.71057-0.21094.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - categorical_accuracy: 0.7685 - loss: 0.5982 - val_categorical_accuracy: 0.2109 - val_loss: 1.7106 - learning_rate: 0.0010
# Epoch 16/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7866 - loss: 0.5429
# Epoch 16: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00016-0.56884-0.77381-2.04810-0.17188.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - categorical_accuracy: 0.7861 - loss: 0.5441 - val_categorical_accuracy: 0.1719 - val_loss: 2.0481 - learning_rate: 0.0010
# Epoch 17/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7910 - loss: 0.5649
# Epoch 17: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00017-0.56887-0.77381-1.99482-0.18750.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 55s 3s/step - categorical_accuracy: 0.7902 - loss: 0.5651 - val_categorical_accuracy: 0.1875 - val_loss: 1.9948 - learning_rate: 0.0010
# Epoch 18/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7561 - loss: 0.5588
# Epoch 18: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00018-0.59560-0.72917-1.43857-0.26562.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 55s 3s/step - categorical_accuracy: 0.7549 - loss: 0.5605 - val_categorical_accuracy: 0.2656 - val_loss: 1.4386 - learning_rate: 0.0010
# Epoch 19/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7901 - loss: 0.5493
# Epoch 19: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00019-0.55944-0.77381-1.64318-0.22656.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - categorical_accuracy: 0.7894 - loss: 0.5498 - val_categorical_accuracy: 0.2266 - val_loss: 1.6432 - learning_rate: 0.0010
# Epoch 20/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8165 - loss: 0.4899
# Epoch 20: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00020-0.51381-0.78720-1.14615-0.34375.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - categorical_accuracy: 0.8152 - loss: 0.4910 - val_categorical_accuracy: 0.3438 - val_loss: 1.1462 - learning_rate: 0.0010
# Epoch 21/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8156 - loss: 0.4976
# Epoch 21: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00021-0.49014-0.81696-1.24715-0.33594.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - categorical_accuracy: 0.8156 - loss: 0.4973 - val_categorical_accuracy: 0.3359 - val_loss: 1.2471 - learning_rate: 0.0010
# Epoch 22/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8439 - loss: 0.4379
# Epoch 22: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00022-0.48241-0.80208-1.11365-0.35938.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 55s 3s/step - categorical_accuracy: 0.8420 - loss: 0.4399 - val_categorical_accuracy: 0.3594 - val_loss: 1.1136 - learning_rate: 0.0010
# Epoch 23/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8334 - loss: 0.4352
# Epoch 23: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00023-0.46277-0.80208-1.12302-0.32812.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 55s 3s/step - categorical_accuracy: 0.8320 - loss: 0.4365 - val_categorical_accuracy: 0.3281 - val_loss: 1.1230 - learning_rate: 0.0010
# Epoch 24/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8600 - loss: 0.3928
# Epoch 24: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00024-0.43433-0.82292-0.86697-0.43750.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - categorical_accuracy: 0.8583 - loss: 0.3947 - val_categorical_accuracy: 0.4375 - val_loss: 0.8670 - learning_rate: 0.0010
# Epoch 25/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8197 - loss: 0.4342
# Epoch 25: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00025-0.46142-0.79613-0.79554-0.64062.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - categorical_accuracy: 0.8186 - loss: 0.4355 - val_categorical_accuracy: 0.6406 - val_loss: 0.7955 - learning_rate: 0.0010
# Epoch 26/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8576 - loss: 0.3988
# Epoch 26: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00026-0.41705-0.82887-0.80100-0.64062.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 55s 3s/step - categorical_accuracy: 0.8563 - loss: 0.3997 - val_categorical_accuracy: 0.6406 - val_loss: 0.8010 - learning_rate: 0.0010
# Epoch 27/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8102 - loss: 0.4866
# Epoch 27: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00027-0.47685-0.81250-0.71531-0.71875.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 55s 3s/step - categorical_accuracy: 0.8103 - loss: 0.4862 - val_categorical_accuracy: 0.7188 - val_loss: 0.7153 - learning_rate: 0.0010
# Epoch 28/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8546 - loss: 0.4223
# Epoch 28: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00028-0.43675-0.81845-0.72304-0.73438.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 55s 3s/step - categorical_accuracy: 0.8530 - loss: 0.4230 - val_categorical_accuracy: 0.7344 - val_loss: 0.7230 - learning_rate: 0.0010
# Epoch 29/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8745 - loss: 0.3959
# Epoch 29: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00029-0.41812-0.86161-0.55218-0.77344.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 55s 3s/step - categorical_accuracy: 0.8739 - loss: 0.3969 - val_categorical_accuracy: 0.7734 - val_loss: 0.5522 - learning_rate: 0.0010
# Epoch 30/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8539 - loss: 0.4068
# Epoch 30: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00030-0.42090-0.83780-0.82665-0.66406.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 55s 3s/step - categorical_accuracy: 0.8531 - loss: 0.4074 - val_categorical_accuracy: 0.6641 - val_loss: 0.8267 - learning_rate: 0.0010
# Epoch 31/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8608 - loss: 0.3764
# Epoch 31: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00031-0.38448-0.84375-0.62498-0.71875.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - categorical_accuracy: 0.8600 - loss: 0.3768 - val_categorical_accuracy: 0.7188 - val_loss: 0.6250 - learning_rate: 0.0010
# Epoch 32/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8638 - loss: 0.3710
# Epoch 32: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00032-0.41075-0.83482-0.68941-0.71875.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - categorical_accuracy: 0.8625 - loss: 0.3728 - val_categorical_accuracy: 0.7188 - val_loss: 0.6894 - learning_rate: 0.0010
# Epoch 33/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8044 - loss: 0.4585
# Epoch 33: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00033-0.42698-0.81845-0.86319-0.67969.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 55s 3s/step - categorical_accuracy: 0.8050 - loss: 0.4570 - val_categorical_accuracy: 0.6797 - val_loss: 0.8632 - learning_rate: 0.0010
# Epoch 34/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8328 - loss: 0.4277
# Epoch 34: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00034-0.44074-0.81548-0.62472-0.53125.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - categorical_accuracy: 0.8320 - loss: 0.4283 - val_categorical_accuracy: 0.5312 - val_loss: 0.6247 - learning_rate: 0.0010
# Epoch 35/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8593 - loss: 0.3692
# Epoch 35: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00035-0.37238-0.83333-0.58602-0.78906.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - categorical_accuracy: 0.8581 - loss: 0.3693 - val_categorical_accuracy: 0.7891 - val_loss: 0.5860 - learning_rate: 0.0010
# Epoch 36/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.9126 - loss: 0.2964
# Epoch 36: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00036-0.37567-0.86607-0.73194-0.72656.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - categorical_accuracy: 0.9105 - loss: 0.3000 - val_categorical_accuracy: 0.7266 - val_loss: 0.7319 - learning_rate: 0.0010
# Epoch 37/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8570 - loss: 0.3772
# Epoch 37: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00037-0.39630-0.83631-0.60306-0.75781.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - categorical_accuracy: 0.8561 - loss: 0.3781 - val_categorical_accuracy: 0.7578 - val_loss: 0.6031 - learning_rate: 0.0010
# Epoch 38/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8673 - loss: 0.3545
# Epoch 38: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00038-0.38362-0.83929-0.90330-0.62500.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - categorical_accuracy: 0.8660 - loss: 0.3558 - val_categorical_accuracy: 0.6250 - val_loss: 0.9033 - learning_rate: 0.0010
# Epoch 39/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8835 - loss: 0.3090
# Epoch 39: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00039-0.36400-0.84524-0.89241-0.64062.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - categorical_accuracy: 0.8817 - loss: 0.3115 - val_categorical_accuracy: 0.6406 - val_loss: 0.8924 - learning_rate: 0.0010
# Epoch 40/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8826 - loss: 0.3609
# Epoch 40: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00040-0.37250-0.84970-0.99888-0.66406.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 53s 3s/step - categorical_accuracy: 0.8811 - loss: 0.3614 - val_categorical_accuracy: 0.6641 - val_loss: 0.9989 - learning_rate: 0.0010
# Epoch 41/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8766 - loss: 0.3760
# Epoch 41: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00041-0.38866-0.84673-1.08244-0.60156.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - categorical_accuracy: 0.8752 - loss: 0.3766 - val_categorical_accuracy: 0.6016 - val_loss: 1.0824 - learning_rate: 0.0010
# Epoch 42/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8975 - loss: 0.3323
# Epoch 42: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00042-0.40078-0.86012-1.05223-0.64062.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - categorical_accuracy: 0.8958 - loss: 0.3354 - val_categorical_accuracy: 0.6406 - val_loss: 1.0522 - learning_rate: 0.0010
# Epoch 43/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8669 - loss: 0.3153
# Epoch 43: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00043-0.37529-0.84375-0.77565-0.64062.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - categorical_accuracy: 0.8659 - loss: 0.3180 - val_categorical_accuracy: 0.6406 - val_loss: 0.7756 - learning_rate: 0.0010
# Epoch 44/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8903 - loss: 0.3067
# Epoch 44: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00044-0.34808-0.86161-0.59522-0.75000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - categorical_accuracy: 0.8890 - loss: 0.3086 - val_categorical_accuracy: 0.7500 - val_loss: 0.5952 - learning_rate: 0.0010
# Epoch 45/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8894 - loss: 0.2966
# Epoch 45: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00045-0.34604-0.85417-0.83110-0.69531.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - categorical_accuracy: 0.8878 - loss: 0.2989 - val_categorical_accuracy: 0.6953 - val_loss: 0.8311 - learning_rate: 0.0010
# Epoch 46/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8693 - loss: 0.3215
# Epoch 46: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00046-0.36851-0.85565-0.66460-0.78906.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - categorical_accuracy: 0.8687 - loss: 0.3236 - val_categorical_accuracy: 0.7891 - val_loss: 0.6646 - learning_rate: 0.0010
# Epoch 47/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.9042 - loss: 0.2740
# Epoch 47: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00047-0.33707-0.86161-0.76572-0.50000.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - categorical_accuracy: 0.9022 - loss: 0.2769 - val_categorical_accuracy: 0.5000 - val_loss: 0.7657 - learning_rate: 0.0010
# Epoch 48/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8905 - loss: 0.3196
# Epoch 48: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00048-0.37180-0.84226-0.58268-0.79688.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - categorical_accuracy: 0.8883 - loss: 0.3220 - val_categorical_accuracy: 0.7969 - val_loss: 0.5827 - learning_rate: 0.0010
# Epoch 49/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.9041 - loss: 0.2856
# Epoch 49: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00049-0.33286-0.86756-0.65375-0.76562.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - categorical_accuracy: 0.9024 - loss: 0.2878 - val_categorical_accuracy: 0.7656 - val_loss: 0.6537 - learning_rate: 0.0010
# Epoch 50/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8948 - loss: 0.2643
# Epoch 50: saving model to model_init_exp_16_2024-11-1915_29_06.163214/model-00050-0.32043-0.86161-1.09965-0.42969.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 55s 3s/step - categorical_accuracy: 0.8933 - loss: 0.2669 - val_categorical_accuracy: 0.4297 - val_loss: 1.0996 - learning_rate: 0.0010

# %%
plt.figure(figsize=(20,6))
ax1 = plt.subplot(121)
ax1 = plt.plot(history.history['loss'])
ax1 = plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
ax2 = plt.subplot(122)
ax2 = plt.plot(history.history['categorical_accuracy'])
ax2 = plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('categorical_accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
